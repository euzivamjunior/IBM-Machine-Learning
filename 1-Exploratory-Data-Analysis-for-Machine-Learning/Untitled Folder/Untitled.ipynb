# %%
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt

# %%
columns = ['age', 'workclass', 'education', 'education-num', 'marital-status', 
           'occupation', 'relationship', 'race', 'sex', 'capital-gain', 
           'capital-loss', 'hours-per-week', 'native-country', '>50K, <=50K']
adult_data = pd.read_csv("adult_data.csv", header = None, names = columns)

# %%
adult_data.head(5)
# Out:
#                   age  workclass   education  education-num  \
# 39          State-gov      77516   Bachelors             13
# 50   Self-emp-not-inc      83311   Bachelors             13
# 38            Private     215646     HS-grad              9
# 53            Private     234721        11th              7
# 28            Private     338409   Bachelors             13
#
#          marital-status          occupation    relationship    race      sex  \
# 39        Never-married        Adm-clerical   Not-in-family   White     Male
# 50   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 38             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 53   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 28   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#     capital-gain  capital-loss  hours-per-week  native-country >50K, <=50K
# ...

# %%
adult_data.shape
# Out:
# (32561, 14)

# %%
adult_data = adult_data.loc[adult_data['capital-gain'] != 0]

# %%
adult_data.head()
# Out:
#            age  workclass   education  education-num       marital-status  \
# 39   State-gov      77516   Bachelors             13        Never-married
# 31     Private      45781     Masters             14        Never-married
# 42     Private     159449   Bachelors             13   Married-civ-spouse
# 30     Private     188146     HS-grad              9   Married-civ-spouse
# 30     Private      59496   Bachelors             13   Married-civ-spouse
#
#             occupation    relationship    race      sex  capital-gain  \
# 39        Adm-clerical   Not-in-family   White     Male          2174
# 31      Prof-specialty   Not-in-family   White   Female         14084
# 42     Exec-managerial         Husband   White     Male          5178
# 30   Machine-op-inspct         Husband   White     Male          5013
# 30               Sales         Husband   White     Male          2407
#
#     capital-loss  hours-per-week  native-country >50K, <=50K
# ...

# %%
adult_data.shape
# Out:
# (2712, 14)
